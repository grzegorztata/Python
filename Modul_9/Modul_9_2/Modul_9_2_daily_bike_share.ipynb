# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
bike_data = pd.read_csv('Files/daily-bike-share.csv', index_col='instant')
display(bike_data)
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1          1/1/2011       1   0     1        0        6           0
# 2          1/2/2011       1   0     1        0        0           0
# 3          1/3/2011       1   0     1        0        1           1
# 4          1/4/2011       1   0     1        0        2           1
# 5          1/5/2011       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 727      12/27/2012       1   1    12        0        4           1
# 728      12/28/2012       1   1    12        0        5           1
# 729      12/29/2012       1   1    12        0        6           0
# 730      12/30/2012       1   1    12        0        0           0
# 731      12/31/2012       1   1    12        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  rentals
# instant
# ...

# %% [markdown]
# #### Związek pogody do liczby wyporzyczonych rowerów

# %%
sns.pairplot(bike_data[['temp','hum','windspeed','rentals']])
plt.show()

# %%
#### Mapowanie obserwacji w zależności od kategorii

# %%
sns.pairplot(bike_data[['season','temp','hum','windspeed','rentals']], hue='season', palette='bright')
plt.show()

# %% [markdown]
# ### Korelacja Pearsona

# %%
plt.figure(figsize=(9,6))
sns.heatmap(bike_data[['temp', 'hum', 'windspeed', 'rentals']].corr(), vmin=-1, vmax=1, annot=True)
plt.show()
