# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(11)
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

""" axes.yaxis.set_major_locator(plt.NullLocator())  # usuwanie znaczników y
axes.xaxis.set_major_formatter(plt.NullFormatter())    # usuwanie znaczników x
axes.xaxis.set_major_formatter(plt.NullFormatter()) """

axes.plot(x,x**2,label='x^2',
          color='red',
          linewidth=3,
          marker='o',
          markersize=20,
          markerfacecolor='orange',
          markeredgewidth=2)
axes.plot(x,x**3,label='x^3',linewidth=3,
          marker='*',
          markersize=10)
