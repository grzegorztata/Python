# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import pandas as pd

# %%
df = pd.read_csv('Files/tmdb_movies.csv')
df.head(5)
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity release_date  \
# ...

# %%
## Ad.1 - Zwróć listę 10 najwyżej ocenianych filmów (vote_average), 
## których liczba głosów (vote_count) jest większa od 3. kwartyla rozkładu liczby głosów
## DataFrame.quantile(q=0.5, axis=0, numeric_only=False, interpolation='linear', method='single')

# %%
vote_count_quantile = df['vote_count'].quantile(0.75)
top_voted_movies = df[df['vote_count'] > vote_count_quantile]

# %%
top_rated_movies = top_voted_movies.sort_values('vote_average', ascending=False)
top_ten_movies = top_rated_movies.head(10)
print(top_ten_movies[['original_title','vote_average','vote_count']])
# Out:
#                 original_title  vote_average  vote_count
# 1881  The Shawshank Redemption           8.5        8205
# 3337             The Godfather           8.4        5893
# 2294                  千と千尋の神隠し           8.3        3840
# 3865                  Whiplash           8.3        4254
# 2731    The Godfather: Part II           8.3        3338
# 3232              Pulp Fiction           8.3        8428
# 1818          Schindler's List           8.3        4329
# 662                 Fight Club           8.3        9413
# 2170                    Psycho           8.2        2320
# 1847                GoodFellas           8.2        3128

# %%
## Ad.2 - Pogrupuj tabelę w taki sposób, aby otrzymać średni przychód (revenue) oraz średni budżet (budget) w danym roku
## dla filmów opublikowanych od 2010 (włącznie) do 2016 roku (włącznie).

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year
movies_in_years = df[(df['year']>=2010)&(df['year']<=2016)]
# Tworzenie nowej tabeli z indexem 'year'
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 df['release_date'] = pd.to_datetime(df['release_date'])
#       2 df['year'] = df['release_date'].dt.year
# ----> 3 movies_in_years = df[(df['year']>=2010)&(df['year']<=2016)].astype(int)
#       5 # Tworzenie nowej tabeli z indexem 'year'
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
# ...
